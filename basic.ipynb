# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
A = np.array([1,2,3])
B = np.array([4,5,6])

# %%
print(A)
# Out:
# [1 2 3]

# %%
print(A+B)
# Out:
# [5 7 9]

# %%
r=1
x = np.linspace(-r,r)
y = np.sqrt(r*r-x*x)

# %%
plt.plot(x,y)
plt.plot(x,-y)
plt.gca().set_aspect('equal')
